# %%
import requests
import pandas as pd
from datetime import datetime

url = 'https://api.vk.com/method/wall.get'
TOKEN = 'bd609931bd609931bd609931e1bd1be35ebbd60bd609931df400a080084c6e2a88bf067'

def get_last_news(group_name, day, time_start, time_end, url=url, token=TOKEN):

    offset = 0
    feed = {}
    
    print(f'Читаю новости {group_name}...')
    # просматриваем по одной новости в цикле от 18.00 до 09.00
    while True:
        params = {
        'domain':group_name,
        'filter':'all',
        'count':1,
        'offset':offset,
        'v':5.131,
        'access_token':token
        }

        post = requests.get(url, params=params).json()['response']['items'][0]
        
        if post['date'] > time_end:
            offset += 1
            continue
        elif post['date'] < time_start:
            print('Прочитано.')
            break
        
        text = post['text']
        if text:
            date = datetime.utcfromtimestamp(post['date']+3600*7).strftime('%Y-%m-%d %H:%M:%S')
            link = 'https://vk.com/vk?w=wall'+str(post['owner_id'])+'_'+str(post['id'])
            feed[date] = [text, link, group_name]
            
        offset += 1

    return feed

vk_groups = [
    'tomsk123',
    'ghest_tomsk',
    'ya_tomich',
    'tomskie',
    'typical_tomsk',
    'tomskvkurse',
    'inctsk',
    'znaigorod',
    'goodcity70',
    'black_list_tomsk',
    'dortom'
]

day = input('Введите дату в формате ГГГГ-ММ-ДД или нажмите Enter для текущего дня:\n')

# попробуем прочитать необходимую дату, если не получится, берем сегодняшний день
if len(day)>0:
    try:
        today = datetime.strptime(day, '%Y-%m-%d').date()
    except Exception as err:
        print('Ошибка: некорректная дата')
        raise(err)
        
else:
    today = datetime.now()

print(f'Читаю новости за {today}')
# Будем читать новости с 9.00 до 18.00
time_start = datetime(today.year, today.month, today.day, 9, 0).timestamp()
time_end = datetime(today.year, today.month, today.day, 18, 0).timestamp()

try:
    df = {}
    for group in vk_groups:
        df.update(get_last_news(group_name=group, day=today, time_start=time_start, time_end=time_end))

    df = pd.DataFrame(df).T
    df.columns = ['text', 'link','group']
    print('Записываю файл excel...')
    df.to_excel(today.strftime('%Y-%m-%d--%H-%M-%S')+'.xlsx')
    print('Готово, можете пользоваться!')
except Exception as err:
    print('Что-то пошло не так',err)

input('Для выхода нажмите Enter.')
# Out:
# Введите дату в формате ГГГГ-ММ-ДД или нажмите Enter для текущего дня:
# 2022-06-14
# Читаю новости за 2022-06-14
# Читаю новости tomsk123...
# Прочитано.
# Читаю новости ghest_tomsk...
# Прочитано.
# Читаю новости ya_tomich...
# Прочитано.
# Читаю новости tomskie...
# Прочитано.
# Читаю новости typical_tomsk...
# Прочитано.
# Читаю новости tomskvkurse...
# Прочитано.
# Читаю новости inctsk...
# Прочитано.
# Читаю новости znaigorod...
# Прочитано.
# Читаю новости goodcity70...
# Прочитано.
# Читаю новости black_list_tomsk...
# Прочитано.
# Читаю новости dortom...
# Прочитано.
# Записываю файл excel...
#                                                                   text  \
# 2022-06-14 14:00:00  В компанию ООО "АБФ Логистик" требуются водите...
# 2022-06-14 13:40:00  ❗️Томичей предупреждают о временном изменении ...
# 2022-06-14 13:10:00  😱 Детская площадка, район авангарда между домо...
# 2022-06-14 12:43:59  ⚠️ ДТП на Путепроводе. Пересечение ул. Пушкина...
# 2022-06-14 12:35:00  ⚡️⚡⚡Все ковидные ограничения сняты в Томской о...
# 2022-06-14 11:35:00  Мы нашли уже 138 обладателей топливных сертифи...
# 2022-06-14 11:10:00  🏎 В России предложили запретить выдачу прав по...
# 2022-06-14 10:40:00  🦌😱 Сбитый лось, около поворота на полигон отхо...
# 2022-06-14 10:35:12              ⚠️ ДТП Интернационалистов - Говорова.
# 2022-06-14 10:10:00                            Доброе утро, Регион 70!
# 2022-06-14 09:40:00  ⚠Так уж бывает, так уж выходит, кто-то теряет,...
# 2022-06-14 13:11:02  ⚡️⚡⚡Все ковидные ограничения сняты в Томской о...
# 2022-06-14 11:40:07  Снова сбили лося 😥\n\nНа этот раз в районе пов...
# 2022-06-14 10:02:00  ⛲ Фонтан постепенно превращается в бассейн 🤔\n...
# 2022-06-14 13:49:36  Дума Томска приняла разработанный администраци...
# 2022-06-14 12:17:04  И.о. томского губернатора Владимир Мазур снял ...
# 2022-06-14 11:42:34  На месте бывшей карандашной фабрики в Томске с...
# 2022-06-14 10:00:01  Из-за жары городские фонтаны постепенно превра...
# 2022-06-14 09:00:00  Томичи с 1 июня имеют право возвращать 5% за Ж...
# 2022-06-14 13:30:00  В Кривошеинском районе сотрудники полиции оказ...
# 2022-06-14 13:02:42  Все ковидные ограничения сняты в Томской облас...
# 2022-06-14 12:19:00  Около 37 тысяч гектаров леса будут восстановле...
# 2022-06-14 10:49:38  Спортсмен-морж из Томска стал одним из основны...
# 2022-06-14 12:39:00                       Прогулка в районе Богашева 🌿
# 2022-06-14 11:07:00  Оказываается, на знаменитой томской мозаике «П...
# 2022-06-14 09:35:00  Пленэр на Университетском озере 🎨\n\nХудожник:...
# 2022-06-14 12:19:32  Владимир Мазур:\n\n"Я решил полностью снять вс...
# 2022-06-14 11:47:42  На территории бывшей карандашной фабрики в Том...
# 2022-06-14 11:44:53  🔥Дети подожгли пух в лесу рядом с Ушакой в Том...
# 2022-06-14 11:39:17  В Томске проводятся плановые санитарные рейды ...
# 2022-06-14 10:47:10  🦌Опять сбили лося. Пишут что возле поворота на...
# 2022-06-14 10:00:00                                          Наш Томск
# 2022-06-14 09:29:34  🛠Газовики завершили пусконаладочные работы на ...
# 2022-06-14 09:01:00  Томичи с 1 июня имеют право возвращать 5% за Ж...
#
#                                                           link       group
# 2022-06-14 14:00:00  https://vk.com/vk?w=wall-60130670_6111507    tomsk123
# 2022-06-14 13:40:00  https://vk.com/vk?w=wall-60130670_6111484    tomsk123
# 2022-06-14 13:10:00  https://vk.com/vk?w=wall-60130670_6111425    tomsk123
# 2022-06-14 12:43:59  https://vk.com/vk?w=wall-60130670_6111376    tomsk123
# 2022-06-14 12:35:00  https://vk.com/vk?w=wall-60130670_6111350    tomsk123
# 2022-06-14 11:35:00  https://vk.com/vk?w=wall-60130670_6111241    tomsk123
# 2022-06-14 11:10:00  https://vk.com/vk?w=wall-60130670_6111168    tomsk123
# 2022-06-14 10:40:00  https://vk.com/vk?w=wall-60130670_6111116    tomsk123
# 2022-06-14 10:35:12  https://vk.com/vk?w=wall-60130670_6111109    tomsk123
# 2022-06-14 10:10:00  https://vk.com/vk?w=wall-60130670_6111080    tomsk123
# 2022-06-14 09:40:00  https://vk.com/vk?w=wall-60130670_6111061    tomsk123
# 2022-06-14 13:11:02   https://vk.com/vk?w=wall-60442626_813596   ya_tomich
# 2022-06-14 11:40:07   https://vk.com/vk?w=wall-60442626_813580   ya_tomich
# 2022-06-14 10:02:00   https://vk.com/vk?w=wall-60442626_813538   ya_tomich
# 2022-06-14 13:49:36   https://vk.com/vk?w=wall-26762265_764650     tomskie
# 2022-06-14 12:17:04   https://vk.com/vk?w=wall-26762265_764588     tomskie
# 2022-06-14 11:42:34   https://vk.com/vk?w=wall-26762265_764569     tomskie
# 2022-06-14 10:00:01   https://vk.com/vk?w=wall-26762265_764521     tomskie
# 2022-06-14 09:00:00   https://vk.com/vk?w=wall-165020798_39449      inctsk
# 2022-06-14 13:30:00   https://vk.com/vk?w=wall-165020798_39481      inctsk
# 2022-06-14 13:02:42   https://vk.com/vk?w=wall-165020798_39476      inctsk
# 2022-06-14 12:19:00   https://vk.com/vk?w=wall-165020798_39470      inctsk
# 2022-06-14 10:49:38   https://vk.com/vk?w=wall-165020798_39454      inctsk
# 2022-06-14 12:39:00   https://vk.com/vk?w=wall-35689602_292259   znaigorod
# 2022-06-14 11:07:00   https://vk.com/vk?w=wall-35689602_292247   znaigorod
# 2022-06-14 09:35:00   https://vk.com/vk?w=wall-35689602_292243   znaigorod
# 2022-06-14 12:19:32  https://vk.com/vk?w=wall-143493022_385463  goodcity70
# 2022-06-14 11:47:42  https://vk.com/vk?w=wall-143493022_385458  goodcity70
# 2022-06-14 11:44:53  https://vk.com/vk?w=wall-143493022_385457  goodcity70
# 2022-06-14 11:39:17  https://vk.com/vk?w=wall-143493022_385456  goodcity70
# 2022-06-14 10:47:10  https://vk.com/vk?w=wall-143493022_385451  goodcity70
# 2022-06-14 10:00:00  https://vk.com/vk?w=wall-143493022_385447  goodcity70
# 2022-06-14 09:29:34  https://vk.com/vk?w=wall-143493022_385443  goodcity70
# 2022-06-14 09:01:00  https://vk.com/vk?w=wall-143493022_385438  goodcity70
# Готово, можете пользоваться!
# Для выхода нажмите Enter.
# ''
