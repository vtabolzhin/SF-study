# %%
import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %%
x = np.arange(-5, 5.1, 0.1)
y = np.arctan(x)

# %%
plt.axvline(x=0, color='black', linestyle='-')
plt.axhline(y=0, color='black', linestyle='-')
plt.axhline(y=math.pi/2, color='r', linestyle='--')
plt.axhline(y=-math.pi/2, color='r', linestyle='--')
plt.plot(x,np.arctan(x))
plt.grid(True)
plt.show()

# %%
plt.axvline(x=0, color='black', linestyle='-')
plt.axhline(y=0, color='black', linestyle='-')
#plt.axhline(y=math.pi/2, color='r', linestyle='--')
#plt.axhline(y=-math.pi/2, color='r', linestyle='--')
plt.plot(x,np.tan(x))
plt.grid(True)
plt.show()

# %%
plt.axvline(x=0, color='black', linestyle='-')
plt.axhline(y=0, color='black', linestyle='-')
#plt.axhline(y=math.pi/2, color='r', linestyle='--')
#plt.axhline(y=-math.pi/2, color='r', linestyle='--')
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))
plt.grid(True)
plt.show()

# %%
x1 = np.arange(-math.pi/2+0.01,math.pi/2,0.01)

# %%
plt.axvline(x=0, color='black', linestyle='-')
plt.axhline(y=0, color='black', linestyle='-')
plt.axvline(x=math.pi/2, color='r', linestyle='--')
plt.axvline(x=-math.pi/2, color='r', linestyle='--')
plt.plot(x1,np.tan(x1))
plt.plot(x1,1/np.tan(x1))
plt.ylim(-20,20)
plt.grid(True)
plt.show()

# %%
plt.axvline(x=0, color='black', linestyle='-')
plt.axhline(y=0, color='black', linestyle='-')
#plt.axhline(y=math.pi/2, color='r', linestyle='--')
#plt.axhline(y=-math.pi/2, color='r', linestyle='--')
plt.plot(x,np.exp(x))
plt.grid(True)
plt.show()

# %%
import math
def func(x1,x2,x3):
    return 1/(1+math.exp(-2*(x1+x2+x3)))

# %%
func(0.1,0.3,0.6)
# Out:
# 0.8807970779778823

# %%
(2.1-1-1)**2 + (2.9 - 1 - 3)**2 + (4.1 - 1 - 5)**2
# Out:
# 4.830000000000002

# %%
x = np.linspace(-5,5,100)
y = np.linspace(-5,5,100)
#=y=n**2
z = x**2+y**2

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, x**2+y**2)
ax.legend()
# Out:
# No handles with labels found to put in legend.

# %%
u, v = np.mgrid[0:2*np.pi:20j, 0:np.pi:10j]
x = np.cos(u)*np.sin(v)
y = np.sin(u)*np.sin(v)
z = np.cos(v)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_wireframe(x, y, z)
ax.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
#ax = Axes3D(fig)
ax = fig.add_subplot(111, projection='3d')
X = np.arange(-2,2,0.1)
Y = np.arange(-2,2,0.1)
X,Y = np.meshgrid(X,Y)

def f(x,y):
    return (1 - y**5 + x**5)*np.exp(-x**2-y**2)

ax.plot_surface(X,Y,f(X,Y), rstride=1, cstride=1)
plt.show()

# %%
f = np.array([8,2,8,3,5,6,5,15])

# %%
plt.plot(f)

# %%
np.gradient(f,7)
# Out:
# array([-0.85714286,  0.        ,  0.07142857, -0.21428571,  0.21428571,
#         0.        ,  0.64285714,  1.42857143])
