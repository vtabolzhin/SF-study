# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
x = np.arange(-5, 5.1, 0.1)
y = np.arctan(x)

# %%
plt.plot(x,y)
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
x = np.arange(-1,1,0.01)
a = 1
def sigmoida(x,a):
    return 1/(1+np.exp(-a*x))

# %%
for a in range(-10,11):
    plt.plot(x,sigmoida(x,a))
plt.show()

# %%
x = np.arange(0.1, 5.1, 0.1)
y1 = np.log(5*x**2)
y2 = np.log(x**2)
y3 = np.log(x)

# %%
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x = np.linspace(0.01, 5, 100)
y1 = np.log(5*x**2)
y2 = np.log(x**2)
y3 = np.log(x)
y4 = 2*np.log(x)

fig, ax = plt.subplots()

ax.plot(x, y1, label = 'log(5*x**2)')
ax.plot(x, y2, label = 'log(x**2)')
ax.plot(x, y3, label = 'log(x)')
ax.plot(x, y4, label = '2*log(x)')

ax.legend()
plt.grid()

fig.set_figheight(5)
fig.set_figwidth(8)
plt.show()
