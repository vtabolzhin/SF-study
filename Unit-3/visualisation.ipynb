# %% [markdown]
# import matplotlib

# %% [markdown]
# matplotlib.__version__

# %% [markdown]
# matplotlib.get_backend()

# %% [markdown]
# matplotlib.use("nbagg")
# print(matplotlib.get_backend())

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot([2,4,4,4,5,6])
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

fig.set(facecolor='green')
ax.set(facecolor='red',
       xlim=[-10,10],
       ylim=[0,1],
       title='Основы анатомии MPL',
       xlabel='Ось абсцисс (xlabel)',
       ylabel='Ось ординат (ylabel)')
plt.show()
