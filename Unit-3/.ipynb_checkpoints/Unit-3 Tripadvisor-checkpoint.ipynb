# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv("main_task_new.csv")
df.head()
# Out:
#   Restaurant_id       City                                      Cuisine Style  \
# 0       id_5569      Paris            ['European', 'French', 'International']
# 1       id_1535  Stockholm                                                NaN
# 2        id_352     London  ['Japanese', 'Sushi', 'Asian', 'Grill', 'Veget...
# 3       id_3456     Berlin                                                NaN
# 4        id_615     Munich  ['German', 'Central European', 'Vegetarian Fri...
#
#    Ranking  Rating Price Range  Number of Reviews  \
# 0   5570.0     3.5    $$ - $$$              194.0
# 1   1537.0     4.0         NaN               10.0
# 2    353.0     4.5        $$$$              688.0
# 3   3458.0     5.0         NaN                3.0
# 4    621.0     4.0    $$ - $$$               84.0
#
#                                              Reviews  \
# 0  [['Good food at your doorstep', 'A good hotel ...
# 1  [['Unique cuisine', 'Delicious Nepalese food']...
# ...

# %%
df.columns
# Out:
# Index(['Restaurant_id', 'City', 'Cuisine Style', 'Ranking', 'Rating',
#        'Price Range', 'Number of Reviews', 'Reviews', 'URL_TA', 'ID_TA'],
#       dtype='object')

# %%
df.columns = ['id', 'city', 'cuisine', 'ranking', 'rating',
       'price_range', 'num_reviews', 'reviews', 'url_ta', 'id_ta']

# %%
sns.heatmap(df.isna())
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           40000 non-null  object
#  1   city         40000 non-null  object
#  2   cuisine      30717 non-null  object
#  3   ranking      40000 non-null  float64
#  4   rating       40000 non-null  float64
#  5   price_range  26114 non-null  object
#  6   num_reviews  37457 non-null  float64
#  7   reviews      40000 non-null  object
#  8   url_ta       40000 non-null  object
#  9   id_ta        40000 non-null  object
# dtypes: float64(3), object(7)
# memory usage: 3.1+ MB

# %%
type(df['reviews'][0])
# Out:
# str

# %%
len(df[df['price_range'] == '$$ - $$$'])
# Out:
# 18412

# %%
df.city.nunique()
# Out:
# 31

# %%
df.cuisine=df.cuisine.str[1:-1].str.split(',').tolist()

# %%
df.explode('cuisine').cuisine.str.strip().value_counts()
# Out:
# 'Vegetarian Friendly'    11189
# 'European'               10060
# 'Mediterranean'           6277
# 'Italian'                 5964
# 'Vegan Options'           4486
#                          ...
# 'Yunnan'                     1
# 'Latvian'                    1
# 'Burmese'                    1
# 'Xinjiang'                   1
# 'Salvadoran'                 1
# Name: cuisine, Length: 125, dtype: int64

# %%
def print_full(df):
    import pandas as pd
    pd.set_option('display.max_rows', len(df))
    print(df)
    pd.reset_option('display.max_rows')

# %%
df['cuisine_count'] = df.cuisine.str.len()
df.cuisine_count = df.cuisine_count.fillna(1)
df.head()
# Out:
#         id       city                                            cuisine  \
# 0  id_5569      Paris          ['European',  'French',  'International']
# 1  id_1535  Stockholm                                                NaN
# 2   id_352     London  ['Japanese',  'Sushi',  'Asian',  'Grill',  'V...
# 3  id_3456     Berlin                                                NaN
# 4   id_615     Munich  ['German',  'Central European',  'Vegetarian F...
#
#    ranking  rating price_range  num_reviews  \
# 0   5570.0     3.5    $$ - $$$        194.0
# 1   1537.0     4.0         NaN         10.0
# 2    353.0     4.5        $$$$        688.0
# 3   3458.0     5.0         NaN          3.0
# 4    621.0     4.0    $$ - $$$         84.0
#
#                                              reviews  \
# 0  [['Good food at your doorstep', 'A good hotel ...
# 1  [['Unique cuisine', 'Delicious Nepalese food']...
# 2  [['Catch up with friends', 'Not exceptional'],...
# ...

# %%
df.cuisine_count.mean()
# Out:
# 2.6224

# %%
df.id.value_counts()
# Out:
# id_227      18
# id_436      18
# id_633      18
# id_871      18
# id_71       17
#             ..
# id_8666      1
# id_3525      1
# id_12956     1
# id_9529      1
# id_9450      1
# Name: id, Length: 11909, dtype: int64

# %%
df2 = pd.DataFrame(df.id_ta.value_counts())
df2 = df2[df2.id_ta > 1]

# %%
df2.index
# Out:
# Index(['d11674463', 'd4600226', 'd7342803', 'd697406', 'd793170', 'd3685055',
#        'd987900', 'd9877640', 'd2477531', 'd11999956', 'd3161682', 'd8753348',
#        'd10047799', 'd7337366', 'd13002276', 'd11698990', 'd11921719',
#        'd9802625', 'd1315077', 'd7809594'],
#       dtype='object')

# %%
df[df.id_ta.isin(df2.index)]
# Out:
#             id    city                                            cuisine  \
# 147    id_4110  Madrid                                        ['Spanish']
# 1579   id_2673  Madrid                                       ['American']
# 3942   id_5646  Madrid  ['Lebanese',  'Mediterranean',  'Middle Easter...
# 4578   id_1180  Madrid  ['Moroccan',  'Vegetarian Friendly',  'Vegan O...
# 4732   id_3804  Madrid  ['American',  'German',  'European',  'Central...
# 5240   id_2406  Madrid                ['Italian',  'French',  'European']
# 8019   id_2361  Madrid  ['Seafood',  'Mediterranean',  'European',  'S...
# 8421   id_3811  Madrid                                        ['Spanish']
# 9446   id_4104  Madrid                                        ['Spanish']
# 10183  id_1225  Madrid  ['Mediterranean',  'European',  'Spanish',  'V...
# 10439   id_468  Madrid  ['Mediterranean',  'Spanish',  'Vegetarian Fri...
# 10594  id_2677  Madrid                                                NaN
# ...

# %%
df[df.id_ta == 'd9877640']
# Out:
#            id    city                                            cuisine  \
# 15295  id_475  Madrid  ['Japanese',  'Vegetarian Friendly',  'Vegan O...
# 15565  id_530  Madrid  ['Japanese',  'Vegetarian Friendly',  'Vegan O...
#
#        ranking  rating price_range  num_reviews  \
# 15295    476.0     4.5    $$ - $$$         67.0
# 15565    531.0     4.5    $$ - $$$         67.0
#
#                                                  reviews  \
# 15295  [['Whenever in Madrid, we never miss this gem....
# 15565  [['Whenever in Madrid, we never miss this gem....
#
#                                                   url_ta     id_ta  \
# 15295  /Restaurant_Review-g187514-d9877640-Reviews-Ra...  d9877640
# 15565  /Restaurant_Review-g187514-d9877640-Reviews-Ra...  d9877640
#
#        cuisine_count
# 15295            4.0
# 15565            4.0

# %%
df3 = df[['id','ranking']]
df3.id = df3.id.apply(lambda x: float(x.replace('id_','')))
df3.head()
# Out:
# c:\users\pc\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py:5494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#        id  ranking
# 0  5569.0   5570.0
# 1  1535.0   1537.0
# 2   352.0    353.0
# 3  3456.0   3458.0
# 4   615.0    621.0

# %%
df.ranking.value_counts()
# Out:
# 1080.0     19
# 431.0      18
# 491.0      18
# 437.0      18
# 345.0      18
#            ..
# 16095.0     1
# 14765.0     1
# 12661.0     1
# 11635.0     1
# 9606.0      1
# Name: ranking, Length: 11936, dtype: int64

# %%
df.id.value_counts()
# Out:
# id_227      18
# id_436      18
# id_633      18
# id_871      18
# id_71       17
#             ..
# id_8666      1
# id_3525      1
# id_12956     1
# id_9529      1
# id_9450      1
# Name: id, Length: 11909, dtype: int64

# %%
df[df.id == 'id_1079']
# Out:
#             id       city                                            cuisine  \
# 967    id_1079     Lisbon  ['Seafood',  'Mediterranean',  'European',  'P...
# 1393   id_1079     Oporto                        ['European',  'Portuguese']
# 5593   id_1079  Barcelona  ['Mediterranean',  'European',  'Spanish',  'V...
# 8231   id_1079   Helsinki                                        ['Italian']
# 9436   id_1079     Madrid  ['International',  'Mediterranean',  'Contempo...
# 11426  id_1079     Warsaw                 ['American',  'Pub',  'Gastropub']
# 11551  id_1079  Stockholm                                            ['Pub']
# 12559  id_1079     Zurich                                                NaN
# 15142  id_1079   Brussels                                                NaN
# 18871  id_1079  Edinburgh                            ['Pizza',  'Fast Food']
# 22051  id_1079      Paris  ['Lebanese',  'Mediterranean',  'Middle Easter...
# ...

# %%
df[['ranking','rating']].corr()
# Out:
#           ranking    rating
# ranking  1.000000 -0.368371
# rating  -0.368371  1.000000

# %%
df[df.ranking >16000]
# Out:
#              id    city                                  cuisine  ranking  \
# 199    id_16034  London                                      NaN  16046.0
# 837    id_16199  London                                      NaN  16211.0
# 949    id_16215  London                                ['Pizza']  16227.0
# 1028   id_16353  London                  ['Fast Food',  'Halal']  16370.0
# 1938   id_16277  London                              ['Chinese']  16289.0
# ...         ...     ...                                      ...      ...
# 38325  id_16388  London                                      NaN  16406.0
# 38330  id_16108  London                                      NaN  16120.0
# 39419  id_16384  London            ['Turkish',  'Mediterranean']  16402.0
# 39443  id_16081  London                              ['Chinese']  16093.0
# 39626  id_16113  London  ['Italian',  'Pizza',  'Mediterranean']  16125.0
#
#        rating price_range  num_reviews  \
# ...

# %%
df[df.reviews.str.contains('nan')].reviews
# Out:
# 1631                [['No impresionante'], ['06/24/2017']]
# 5315     [['Will certainly be back', nan], ['11/26/2017...
# 12643    [['buckwheat crepes (au sarrasin)', 'Crepe wit...
# 14650    [['"The" bar to visit in Bonanova', 'Not expen...
# 19090    [['Ark of the Covenant', 'Average food, unsati...
# 21678    [['Nasty cheap', 'Penang Beef good, red and gr...
# 21878    [['I needed sustenance and a coffee after an.....
# 22958    [[nan, 'Good food with decent service'], ['11/...
# 28206    [['Friendly staff, good food', 'I want this ba...
# 29031    [['Delicious', 'Great Panang Curry'], ['11/13/...
# 30457    [['Good coffee, great atmosphere', 'Good coffe...
# 34516    [['Decent spanish food', 'Good food/parrillada...
# 38256    [['Really good flammkuchenand nice atmosphere....
# 39711    [['Not many noodle dishes', 'Great Henan and S...
# Name: reviews, dtype: object

# %%
nan = None
df['rev_txt'] = df.reviews.apply(lambda x: eval(x)[0])
df['rev_date'] = df.reviews.apply(lambda x: eval(x)[1])

# %%
df.head()
# Out:
#         id       city                                            cuisine  \
# 0  id_5569      Paris          ['European',  'French',  'International']
# 1  id_1535  Stockholm                                                NaN
# 2   id_352     London  ['Japanese',  'Sushi',  'Asian',  'Grill',  'V...
# 3  id_3456     Berlin                                                NaN
# 4   id_615     Munich  ['German',  'Central European',  'Vegetarian F...
#
#    ranking  rating price_range  num_reviews  \
# 0   5570.0     3.5    $$ - $$$        194.0
# 1   1537.0     4.0         NaN         10.0
# 2    353.0     4.5        $$$$        688.0
# 3   3458.0     5.0         NaN          3.0
# 4    621.0     4.0    $$ - $$$         84.0
#
#                                              reviews  \
# 0  [['Good food at your doorstep', 'A good hotel ...
# 1  [['Unique cuisine', 'Delicious Nepalese food']...
# 2  [['Catch up with friends', 'Not exceptional'],...
# ...

# %%
df.rev_date.apply(len).value_counts()
# Out:
# 2    28973
# 0     6471
# 1     4556
# Name: rev_date, dtype: int64

# %%
df.rev_txt.apply(len).value_counts()
# Out:
# 2    28973
# 0     6471
# 1     4556
# Name: rev_txt, dtype: int64

# %%
df.rev_date[0][0]
# Out:
# '12/31/2017'

# %%
from datetime import datetime
dt = datetime.strptime(df.rev_date[0][0], '%m/%d/%Y')
dt.day
# Out:
# 31

# %%
dt_str = datetime.strftime(dt, '%d-%m-%Y')
dt_str
# Out:
# '31-12-2017'

# %%
def get_date(cell):
    if len(cell):
        cell = pd.to_datetime(cell, errors='coerce', format='%m/%d/%Y')
    return cell

# %%
df.rev_date = df.rev_date.apply(get_date)

# %%
def time_delta(cell):
    if len(cell)<2:
        return 0
    return np.abs((cell[0] - cell[1]).days)

# %%
df['rev_date_delta'] = df.rev_date.apply(time_delta)

# %%
df.rev_date_delta.value_counts()
# Out:
# 0       11519
# 1         664
# 2         523
# 3         496
# 4         431
#         ...
# 780         1
# 812         1
# 2425        1
# 1356        1
# 1631        1
# Name: rev_date_delta, Length: 1228, dtype: int64

# %%
df[df.rev_date_delta == df.rev_date_delta.max()].reviews.iloc[0]
# Out:
# "[['Incredible buffet!', 'Used to be great, but still good under new...'], ['10/02/2016', '12/22/2007']]"

# %%
def fresh_review(cell):
    if len(cell) == 0:
        return 0
    if len(cell) < 2:
        return cell
    return cell.max()

# %%
df['fresh_rev'] = df.rev_date.apply(fresh_review)

# %%
df[df.fresh_rev!=0].fresh_rev.max()
# Out:
# Timestamp('2018-02-26 00:00:00')
