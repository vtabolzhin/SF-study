# %%
print("hello,World")
# Out:
# hello,World

# %%
((67+33)*(25-20))/25
# Out:
# 20.0

# %%
(4+5*60-17+65/4)**(1/2)
# Out:
# 17.414074767267998

# %%
6.996+45*((13/2)**2)+2*(18**(1/2))
# Out:
# 1916.7312813742387

# %%
(1267-20*(((5**3)/2)**2))/((8**5)*(36**(1/2)))
# Out:
# -0.3909200032552083

# %%
((9**(1/2))**(3*2*2))/(-2**(-3))
# Out:
# -4251528.0

# %%
print('hey'+'!')
# Out:
# hey!

# %%
type(2+3.4)
# Out:
# float

# %%
'hey'+'!'
# Out:
# 'hey!'

# %%
a=int(float('2.6'))
print(a)
type(a)
# Out:
# 2
# int

# %%
type(4 ** (1/2))
# Out:
# float

# %%
multiplier = int(input('Введите множитель числа 5:\n'))
print('Результат:', 5*multiplier)
# Out:
# Введите множитель числа 5:
# 8565
# Результат: 42825

# %%
word = 'Очаровательно'
len(word)
# Out:
# 13

# %%
a = 117
b = 23
print(a%b)
# Out:
# 2

# %%
a = int(input())
b = int(input())

if a == b:
    print('Введены одинаковые числа')
else:
    print('Введены разные числа')
# Out:
# 1
# 4
# Введены разные числа

# %%
x = 5
y = 10
y > x * x or y >= 2 * x and x < y
# Out:
# True

# %%
"239" < "30"
# Out:
# True

# %%
number = 348
print(number%2)
if not number%2:
    print('ok')
# Out:
# 0
# ok

# %%
fav_word = 'змея'
if fav_word in ['рептилия','питон','змея']:
    print('Python')
# Out:
# Python

# %%
hour = 15
minute = 47
if (hour==10 and 0<=minute<30) or (hour==12 and 0<minute<59) or (hour==13 and 0<=minute<40) or (15<=hour<=17 and 0<minute<=59) or (hour==19 and 30<minute<=59):
    print('Преподаватель свободен.')
else:
    print('Преподаватель занят.')
# Out:
# Преподаватель свободен.

# %%
word = 'подшипник'
for i,letter in enumerate(word):
    if (i+1)%2:
        print(letter)
# Out:
# п
# д
# и
# н
# к

# %%
year_1 = 2013
year_2 = 2020
for i in range(year_1,year_2+1):
    if i%4:
        print(i,'год невисокосный')
    else:
        print(i,'год високосный')
# Out:
# 2013 год невисокосный
# 2014 год невисокосный
# 2015 год невисокосный
# 2016 год високосный
# 2017 год невисокосный
# 2018 год невисокосный
# 2019 год невисокосный
# 2020 год високосный

# %%
word = 'Зимушка-зима'
for i,letter in enumerate(word):
    if letter in ('а', 'у', 'о', 'ы', 'и', 'э', 'я', 'ю', 'ё', 'е'):
        print(letter)
# Out:
# и
# у
# а
# и
# а

# %%
name = 'Сергей'
for i,letter in enumerate(name):
    print('Буква',(i+1),'в этом имени -',letter)
# Out:
# Буква 1 в этом имени - С
# Буква 2 в этом имени - е
# Буква 3 в этом имени - р
# Буква 4 в этом имени - г
# Буква 5 в этом имени - е
# Буква 6 в этом имени - й

# %%
num_1 = 25
num_2 = 45
if num_2<num_1 or num_1<0:
    print('Введён неверный диапазон чисел')
else:    
    for i in range(num_1,num_2+1):
        if i%2 and (not i%3 or not i%5):
            print(i)
# Out:
# 25
# 27
# 33
# 35
# 39
# 45

# %%
for i in range(1,10+1):
    print(i,i**2,i**3)
# Out:
# 1 1 1
# 2 4 8
# 3 9 27
# 4 16 64
# 5 25 125
# 6 36 216
# 7 49 343
# 8 64 512
# 9 81 729
# 10 100 1000

# %%
#number = int(input())
number = 84
for i in range(1,number+1):
    if not number%i:
        print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 12
# 14
# 21
# 28
# 42
# 84

# %%
#num_1 = int(input())
#num_2 = int(input())
num_1 = 12
num_2 = 38
for i in range(2,min(num_1,num_2)+1):
    if num_1%i == num_2%i == 0:
        print(i)
# Out:
# 2

# %%
n = 10
a=1
b=1
for i in range(n-2):
    a,b=b,b+a
print(b)
# Out:
# 55

# %%
number = 15
for i in range(1,11):
    print(number,'X',i,'=',number*i)
# Out:
# 15 X 1 = 15
# 15 X 2 = 30
# 15 X 3 = 45
# 15 X 4 = 60
# 15 X 5 = 75
# 15 X 6 = 90
# 15 X 7 = 105
# 15 X 8 = 120
# 15 X 9 = 135
# 15 X 10 = 150

# %%
#num_1 = int(input())
#num_2 = int(input())
num_1 = 1812
num_2 = 2500
for i in range(min(num_1,num_2),1,-1):
    if num_1%i == num_2%i == 0:
        print(i)
        break
else:
    print('Общих делителей не найдено')
# Out:
# итерация 1812
# итерация 1811
# итерация 1810
# итерация 1809
# итерация 1808
# итерация 1807
# итерация 1806
# итерация 1805
# итерация 1804
# итерация 1803
# итерация 1802
# итерация 1801
# итерация 1800
# итерация 1799
# итерация 1798
# итерация 1797
# итерация 1796
# итерация 1795
# итерация 1794
# итерация 1793
# итерация 1792
# итерация 1791
# итерация 1790
# итерация 1789
# итерация 1788
# итерация 1787
# итерация 1786
# итерация 1785
# итерация 1784
# итерация 1783
# итерация 1782
# итерация 1781
# итерация 1780
# итерация 1779
# итерация 1778
# итерация 1777
# итерация 1776
# итерация 1775
# итерация 1774
# итерация 1773
# итерация 1772
# итерация 1771
# итерация 1770
# итерация 1769
# итерация 1768
# итерация 1767
# итерация 1766
# итерация 1765
# итерация 1764
# итерация 1763
# итерация 1762
# итерация 1761
# итерация 1760
# итерация 1759
# итерация 1758
# итерация 1757
# итерация 1756
# итерация 1755
# итерация 1754
# итерация 1753
# итерация 1752
# итерация 1751
# ...

# %%
#string = input()
string = 'абстракция'
for i,letter in enumerate(string):
    if letter in ('а','б','в'):
        continue
    print(letter,end='')
# Out:
# стркция

# %%
string = 'Нет'
for i in range(5):
    if string == 'Да':
        print('Это отлично!')
        break
    else:
        print('Увы, это неправильный ответ')
else:
    print('Это безнадёжно!')
# Out:
# Увы, это неправильный ответ
# Увы, это неправильный ответ
# Увы, это неправильный ответ
# Увы, это неправильный ответ
# Увы, это неправильный ответ
# Это безнадёжно!

# %%
#Y = int(input())
#Z = int(input())
Y = 170000
Z = 1000000
muliplier = 1.1
year = 0
while Y < Z:
    Y*=muliplier
    year +=1
else:
    print(year)
# Out:
# 19

# %%
#Y = int(input())
#Z = int(input())
Y = 170000
Z = 1000000
year = 0
yearly_multiplier = 1.1

while money < 2:
    money = money*yearly_multiplier
    year += 1
else:
    print('Деньги удвоятся через', year, 'лет')
# Out:
# Деньги удвоятся через 12 лет

# %%
weight = 77
total_weight = 0
overweight = 400
while total_weight<overweight:
    total_weight += weight
else:
    print('Перевес',total_weight-overweight,'кг')
# Out:
# Перевес 62 кг

# %%
str1 = 'a'
str2 = 'b'
print(str1+str2)
#print(str1/str2)
#print(str1*str2)
#print(str1**str2)
#print(str1%str2)
#print(str1//str2)
# Out:
# ab

# %%
n = 10

fib1 = 1
fib2 = 1
if n == 0:
    print(0)
elif n <= 2:
    print(1)
else:
    for n in range(2, n):
        fib_sum = fib1 + fib2
        fib1 = fib2
        fib2 = fib_sum
    else:
        print(fib2)
# Out:
# 55
