# %%
import pandas as pd

# %%
df = pd.read_csv("data_sf.csv")
df.tail()
# Out:
#        Unnamed: 0                Name  Age Nationality              Club  \
# 12892       13121        J. Lundstram   19     England   Crewe Alexandra
# 12893       13122  N. Christoffersson   19      Sweden    Trelleborgs FF
# 12894       13123           B. Worman   16     England  Cambridge United
# 12895       13124      D. Walker-Rice   17     England   Tranmere Rovers
# 12896       13125           G. Nugent   16     England   Tranmere Rovers
#
#          Value  Wage Position  Crossing  Finishing  ...  Penalties  Composure  \
# 12892  1100000  1000       CM        34         38  ...         43         45
# 12893    60000  1000       ST        23         52  ...         43         42
# 12894    60000  1000       ST        25         40  ...         55         41
# 12895    60000  1000       RW        44         50  ...         50         46
# 12896    60000  1000       CM        41         34  ...         33         43
#
# ...

# %%
df_small = df[df.columns[1:8]].head(25)
df_small
# Out:
#                  Name  Age Nationality                 Club      Value  \
# 0            L. Messi   31   Argentina         FC Barcelona  110500000
# 1   Cristiano Ronaldo   33    Portugal             Juventus   77000000
# 2           Neymar Jr   26      Brazil  Paris Saint-Germain  118500000
# 3              De Gea   27       Spain    Manchester United   72000000
# 4        K. De Bruyne   27     Belgium      Manchester City  102000000
# 5           E. Hazard   27     Belgium              Chelsea   93000000
# 6           L. Modrić   32     Croatia          Real Madrid   67000000
# 7           L. Suárez   31     Uruguay         FC Barcelona   80000000
# 8        Sergio Ramos   32       Spain          Real Madrid   51000000
# 9            J. Oblak   25    Slovenia      Atlético Madrid   68000000
# 10     R. Lewandowski   29      Poland    FC Bayern München   77000000
# 11           T. Kroos   28     Germany          Real Madrid   76500000
# ...

# %%
s = df_small.Nationality.value_counts()
s
# Out:
# Spain        4
# Belgium      3
# Argentina    3
# Uruguay      3
# Germany      3
# France       2
# Italy        1
# Slovenia     1
# Portugal     1
# England      1
# Croatia      1
# Poland       1
# Brazil       1
# Name: Nationality, dtype: int64

# %%
# value_counts() на выходе дает Series, в котором индексы - уникальные значения, а в столбце -
# отсрортированные по убыванию количетво повторений. поэтому самый быстрый способ посчитать, из какой страны больше всего футболистов
s.index[0]
# Out:
# 'Spain'

# %%
# количество различных национальностей в нашем сете:
len(s)
# Out:
# 13

# %%
s>1
# Out:
# Spain         True
# Belgium       True
# Argentina     True
# Uruguay       True
# Germany       True
# France        True
# Italy        False
# Slovenia     False
# Portugal     False
# England      False
# Croatia      False
# Poland       False
# Brazil       False
# Name: Nationality, dtype: bool

# %%
s[s>1]
# Out:
# Spain        4
# Belgium      3
# Argentina    3
# Uruguay      3
# Germany      3
# France       2
# Name: Nationality, dtype: int64

# %%
df.Club.value_counts().tail()
# Out:
# FC Metz              8
# Dinamo Zagreb        7
# GD Chaves            7
# Vitória Guimarães    7
# Atlético Mineiro     6
# Name: Club, dtype: int64

# %%
s = df.Position.value_counts(normalize = True)
s[s<0.01]
# Out:
# LS     0.009382
# RS     0.008839
# RWB    0.005428
# LWB    0.004652
# CF     0.003954
# LF     0.000620
# LAM    0.000465
# RF     0.000465
# RAM    0.000388
# Name: Position, dtype: float64

# %%
s = df.Wage.value_counts(bins = 4)
s
# Out:
# (435.999, 142000.0]     12818
# (142000.0, 283000.0]       61
# (283000.0, 424000.0]       16
# (424000.0, 565000.0]        2
# Name: Wage, dtype: int64

# %%
df[(df.Wage > s.index[len(s)-1].left)&(df.Wage <= s.index[len(s)-1].right)]
# Out:
#    Unnamed: 0       Name  Age Nationality          Club      Value    Wage  \
# 0           0   L. Messi   31   Argentina  FC Barcelona  110500000  565000
# 7           7  L. Suárez   31     Uruguay  FC Barcelona   80000000  455000
#
#   Position  Crossing  Finishing  ...  Penalties  Composure  Marking  \
# 0       RF        84         95  ...         75         96       33
# 7       RS        77         93  ...         85         85       62
#
#    StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  \
# 0              28             26         6          11         15
# 7              45             38        27          25         31
#
#    GKPositioning  GKReflexes
# 0             14           8
# 7             33          37
#
# [2 rows x 42 columns]

# %%
df.FKAccuracy.value_counts(bins=5)
# Out:
# (21.2, 39.4]     4859
# (39.4, 57.6]     3957
# (57.6, 75.8]     2108
# (2.908, 21.2]    1760
# (75.8, 94.0]      213
# Name: FKAccuracy, dtype: int64
